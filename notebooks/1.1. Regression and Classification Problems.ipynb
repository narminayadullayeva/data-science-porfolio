# %% [markdown]
# # Exercise: Dataset Principles
#
# Since models are nothing without data, it's important to make sure the fundamentals are strong when creating and shaping your datasets. Here we'll create a regression dataset and split it into the three core dataset types: train, validation, and test.
#
# Your tasks for this exercise are:
# 1. Create a dataframe with your features and target arrays from `make_regression`.
# 2. Create a 60% Train / 20% Validation / 20% Test dataset group using the `train_test_split` method.
# 3. Confirm the datasets are the correct size by outputing their shape.
# 4. Save the three datasets to CSV

# %%
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
# Creating a regression dataset with 1000 samples, 5 feature columns, 2 which are actually useful, and 1 target column
regression_dataset = make_regression(
    n_samples=1000, n_features=5, n_informative=2, n_targets=1, random_state=0
)

# %%
regression_dataset[0].shape
# Out:
# (1000, 5)

# %%
regression_dataset[1].shape
# Out:
# (1000,)

# %%
df = pd.DataFrame(regression_dataset[0])
df["target"] = regression_dataset[1]
df
# Out:
#             0         1         2         3         4      target
# 0    0.236225 -0.323289 -0.018429 -1.548471  1.311427   70.618083
# 1   -0.801497  0.271170 -0.525641 -0.887780  0.936399   52.757870
# 2    0.687881  0.417044 -1.203735  0.498727 -0.737932  -43.728456
# 3   -0.679593 -1.063433 -1.797456  0.913202  2.211304  156.835125
# 4    0.096479 -0.507060  0.522083  0.155794  1.520004  102.748706
# 5   -1.672445  0.483472  0.406657 -0.967127 -1.010546  -77.563114
# 6    0.915603  0.281697  0.279689 -0.254962  0.956809   60.895473
# 7   -0.326318  0.512836 -0.468476 -1.348424 -0.401558  -41.151104
# 8    0.123960  0.414307 -1.859524 -2.046393 -1.809690 -142.269605
# 9    0.280078 -0.504553  1.997626  0.590259 -0.292061  -13.097531
# 10  -0.777148 -1.034795 -0.654487  0.112308  0.392374   27.296014
# 11  -0.971105  0.276872  0.868963 -0.466846 -1.416906  -99.225555
# 12   0.825217  0.528439 -0.508675 -2.368803  1.322194   62.544607
# 13  -1.112906 -1.037029  0.080720 -0.837776  0.909188   51.484184
# 14   0.402342 -1.234826  1.139401  0.729091  0.128983   16.389161
# 15   0.640948 -0.984083  1.838181  1.209772 -1.264800  -71.146408
# 16   1.274045  0.865525  0.490971 -0.307132 -0.449037  -33.151510
# 17  -1.065148 -1.186382  1.140460 -0.469546 -0.049611   -8.330053
# 18   0.092448  1.530932  0.042539 -1.451338  0.021857  -14.096909
# 19  -0.762115 -0.212523  0.059895  1.326462 -0.964606  -49.933412
# 20  -1.998639 -0.289005 -0.132568  0.460814  0.923797   66.369404
# 21   0.203540 -1.510200  3.306574 -0.387313 -0.347585  -27.264072
# 22   2.149575 -0.733313 -1.638807 -0.879161 -0.231102  -24.787932
# 23  -1.279689  0.064856  1.224871 -2.239604  0.401499    2.703170
# 24  -0.041401 -1.359781  0.422629  0.148450  0.529045   36.771802
# 25  -0.980459  0.157069 -0.536333 -0.909032 -0.145170  -19.393602
# 26   0.395437 -0.095871 -0.096942  0.801301 -0.003331    8.364026
# 27   0.817862 -1.309412 -1.482883 -0.855240  1.257220   74.440955
# 28  -0.420606 -0.291113 -1.190456 -0.431303 -1.737050 -120.134108
# 29  -0.711041 -0.060362 -0.670126 -0.291041  0.554128   33.730824
# ..        ...       ...       ...       ...       ...         ...
# 970 -0.415002  0.172825  1.140488 -0.741056  0.060009   -3.949491
# 971 -0.027145  1.369402  0.040191 -1.151150 -1.482476 -110.917919
# 972  0.089620 -0.825779 -0.395222  1.010694 -0.743228  -38.595137
# 973  0.272796 -0.470742  0.183450 -0.555985  0.026738   -4.179031
# 974  0.982327  0.174630 -1.003266  1.697346 -0.566603  -19.492535
# 975  1.161534  0.205087  0.382203  1.936712 -1.451906  -75.799999
# 976 -2.129246  0.567708 -0.306873  1.187894  1.016027   80.293023
# 977  1.033957  0.303656 -0.473604 -0.453337  0.892708   54.507332
# 978 -1.949572 -0.053138 -0.045383  0.139827  1.738857  117.131281
# 979  1.431443 -0.150595  1.145361 -1.733861 -1.640601 -127.676640
# 980 -0.172201  1.324359  0.377910  1.769921 -0.168214    7.777720
# 981 -0.042257  2.259309  0.379152 -0.410050 -0.017020   -5.525339
# 982  1.488252 -1.536244  0.465662 -1.165150  0.900826   47.420460
# 983  2.383145  0.635031  0.166673 -1.491258  0.439392   13.241194
# 984  0.239087 -0.973376 -1.306522 -1.093895  0.205797    1.964808
# 985 -0.518679 -1.292001  1.320794  0.433119 -0.210189   -9.336783
# 986 -0.782367 -0.348046 -0.255958  0.602708 -0.594650  -33.086172
# 987 -0.836111 -1.150438 -1.021913 -0.069856  0.250114   15.883966
# 988 -0.842494 -0.178371 -1.999268 -0.102763 -0.182314  -13.224858
# 989 -1.297380 -0.073120 -0.521642  0.625119 -0.813596  -47.405859
# 990  0.871758 -0.637439  0.746814 -0.210208 -0.444203  -31.791549
# 991 -1.518207  0.303452 -1.419186 -0.053243 -0.773500  -52.007796
# 992  0.282678  0.537397  0.412272 -1.263728  1.665049   97.184674
# 993 -0.628981 -1.431798  0.500017 -0.011136  1.344074   89.260937
# 994  1.825886 -0.918519  0.400640 -0.488695  0.409982   22.027479
# 995  1.608522 -0.952645  0.160661  0.502328 -0.862267  -51.958097
# 996  1.076200  0.215930  1.507616  0.458680  1.192809   84.235700
# 997 -0.028529 -0.309378  0.284791  0.886492 -0.272132   -8.598279
# 998 -0.937948  0.711785 -0.288131 -1.410823  0.164913   -4.149700
# 999 -0.656464  0.867407  0.755396 -0.591403  1.124419   68.436691
#
# [1000 rows x 6 columns]

# %%
df.head()
# Out:
#           0         1         2         3         4      target
# 0  0.236225 -0.323289 -0.018429 -1.548471  1.311427   70.618083
# 1 -0.801497  0.271170 -0.525641 -0.887780  0.936399   52.757870
# 2  0.687881  0.417044 -1.203735  0.498727 -0.737932  -43.728456
# 3 -0.679593 -1.063433 -1.797456  0.913202  2.211304  156.835125
# 4  0.096479 -0.507060  0.522083  0.155794  1.520004  102.748706

# %%
# Create a train: 0.8 | test: 0.2 ratio dataset
df_train, df_test = train_test_split(data = df, train_size = 0.8)

# Create a train: 0.6 | validation: 0.2 ratio dataset
df_train, df_val = train_test_split(data = df_train, train_size = 0.6)

# Final dataset sizes: train: 0.6, validation: 0.2, test: 0.2,
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-03b9b74da9df> in <module>()
#       1 # Create a train: 0.8 | test: 0.2 ratio dataset
# ----> 2 df_train, df_test = train_test_split(data = df, train_size = 0.8)
#       3
#       4 # Create a train: 0.6 | validation: 0.2 ratio dataset
#       5 df_train, df_val = train_test_split(data = df_train, train_size = 0.6)
#
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2008     n_arrays = len(arrays)
#    2009     if n_arrays == 0:
# -> 2010         raise ValueError("At least one array required as input")
#    2011     test_size = options.pop('test_size', 'default')
#    2012     train_size = options.pop('train_size', None)
#
# ValueError: At least one array required as input

# %%
# Output each shape to confirm the size of train/validation/test
print(f"Train: {?}")
print(f"Validation: {?}")
print(f"Test: {?}")

# %%
# Output all datasets to csv
df_train.to_csv(?)
df_val.to_csv(?)
df_test.to_csv(?)
